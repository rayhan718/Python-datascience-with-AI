# %%
class BankAccount:
    def __init__(self, name, balance, pin):
        self.name = name
        self.balance = balance
        self.__pin = pin

    def display_balance(self):
        print(f"Owner: {self.name} | Balance = {self.balance}")

    def withdraw(self, amount):
        PIN = int(input("Enter PIN: "))

        if PIN == self.__pin:
            if amount <= self.balance:
                self.balance -= amount
                print(f"{amount} withdrawn successfully.")
                print(f"Remaining balance: {self.balance}")
                return self.balance
            else:
                print("Insufficient balance.")
        else:
            print("Incorrect PIN. Transaction denied.")

    def deposit(self, amount):
        PIN = int(input("Enter PIN: "))

        if PIN == self.__pin:
            self.balance += amount
            print(f"{amount} deposited successfully.")
            print(f"Current balance: {self.balance}")
            return self.balance
        else:
            print("Incorrect PIN. Transaction denied.")


account = BankAccount("Delphine", 5000, 123)

account.display_balance()

account.deposit(1500)

account.display_balance()

account.withdraw(2000)

account.withdraw(1000)
# Out:
# Owner: Delphine | Balance = 5000
# Enter PIN:  123
# 1500 deposited successfully.
# Current balance: 6500
# Owner: Delphine | Balance = 6500

# %%
print("hai")
# Out:
# hai

# %%
class BankAccount:
    def __init__(self,owner,balance):
        self.owner=owner
        self._balance=balance
        self.__pain=1234
    def get_balance(self):
        return f"Balance:{self._balance}"

acct = BankAccount("Alice",5000)
print(acct.owner)
print(acct.get_balance())
print(acct._balance)

acc2 = BankAccount("Archana",6000)
print(acc2.owner)
print(acc2.get_balance())
print()


acc3 = BankAccount("Delphine",4000)
print(acc3.owner)
print(acc3.get_balance())
print()

acc4=BankAccount("Nimi",8000)
print(acc4.owner)
print(acc4.get_balance())
print()
# Out:
# Alice
# Balance:5000
# 5000
# Archana
# Balance:6000
#
# Delphine
# Balance:4000
#
# Nimi
# Balance:8000

# %%
class Student:
    stuCount = 0
    def __init__(self,name,grade):
        self.name = name
        self.grade = grade
        Student.stuCount +=1
    def displaycount(self): 
       print("Total Student  %d" % Student.stuCount)
    def displayStudent(self):
        print("Name:",self.name, ",Grade:",self.grade)

stu1 = Student("Alice","A")
stu2 = Student("John","B")
stu3 = Student("Sanjay","A")

stu1.displayStudent()
stu2.displayStudent()
stu3.displayStudent()

print("Total student %d" % Student.stuCount)
# Out:
# Name: Alice ,Grade: A
# Name: John ,Grade: B
# Name: Sanjay ,Grade: A
# Total student 3

# %%
class Student:
    def __init__(self,name,roll_no,age,marks):
        self.name = name
        self.roll_no=roll_no
        self.age=age
        self.marks=marks

    def display_details(self):
        print(f"name:{self.name}")
        print(f"Name No :{self.name}")
        print(f"Age:{self.roll_no}")
        print(f"Age:{self.age}")
        print(f"MArks:{self.marks}")


    def update_marks(self,new_marks):
        self.marks = new_marks
        print(f"{self.name}'s marks updated to {self.marks}")

student1 = Student("Aditya", 101,18,85)
student2 = Student("priya",102,19,90)

print("===Student 1 Details ===")
student1.display_details()
print("\n===Student 2 Details ===")
student2.display_details()


print("\n===Update marks...")
student1.update_marks(92)

print("\n===updated student Details ===")
student1.display_details()
# Out:
# ===Student 1 Details ===
# name:Aditya
# Name No :Aditya
# Age:101
# Age:18
# MArks:85
#
# ===Student 2 Details ===
# name:priya
# Name No :priya
# Age:102
# Age:19
# MArks:90
#
# ===Update marks...
# Aditya's marks updated to 92
#
# ===updated student Details ===
# name:Aditya
# Name No :Aditya
# Age:101
# Age:18
# MArks:92

# %%
class BankAccount:
    def __init__(self,name,balance,pin):
        self.name=name
        self.balance=balance
        self.__pin=pin


    def display_balance(self):
        print(f"Owner:{self.name} | Balance={self.balance}")
        
    def withdraw(self,amount):
        
        PIN=int(input("Enter PIN:"))
        if PIN==self.__pin:
            self.balance-=amount
            print(f"{amount} withdraw successfully.Remaining balance :{self.balance}")
            return self.balance
                  
        else:
             print(f"Incorrect PIN. Transaction Denied")

    def deposit(self,amount):
        PIN=int(input("ENTER PIN :"))
        if PIN==self.__pin:
            self.balance+=amount
            print(f"{amount} deposited")
            return self.balance
        else:
            print("Incorrect PIN .")
            

            
account=BankAccount("Delphine",5000,1234)
account.display_balance()
account.deposit(1500)
account.display_balance()
account.withdraw(2000)
account.withdraw(1000)
print("Thank you")
# Out:
# Owner:Delphine | Balance=5000
# ENTER PIN : 1234
# 1500 deposited
# Owner:Delphine | Balance=6500
# Enter PIN: 123
# Incorrect PIN. Transaction Denied
